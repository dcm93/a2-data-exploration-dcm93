# %%
import pandas as pd

# %%
def strip(text):
    try:
        return text.strip()
    except AttributeError:
        return text

# %%
beers = pd.read_csv('../data/beers.csv')
beers['ibu'].fillna(-1, inplace=True)
beers['abv'].fillna(-1, inplace=True)

# %%
beers_ibu = beers[(beers['ibu'] != -1) & (beers['abv'] !=-1)]
beers_final = beers_ibu.drop_duplicates(subset='name')

# %%
beers_final
# Out:
#       Unnamed: 0    abv    ibu    id  \
# 14            14  0.061   60.0  1979
# 21            21  0.099   92.0  1036
# 22            22  0.079   45.0  1024
# 24            24  0.044   42.0   876
# 25            25  0.049   17.0   802
# 27            27  0.049   17.0   800
# 28            28  0.070   70.0   799
# 29            29  0.070   70.0   797
# 30            30  0.070   70.0   796
# 31            31  0.085   52.0   531
# 32            32  0.097   94.0   432
# 33            33  0.044   42.0   353
# 34            34  0.079   45.0   321
# 35            35  0.068   65.0   173
# 36            36  0.083   35.0    11
# 37            37  0.070   65.0    10
# 38            38  0.049   17.0     9
# 39            39  0.070   82.0  2519
# 42            42  0.035   11.0  2545
# 43            43  0.045   18.0  2544
# 49            49  0.050   28.0  1870
# 51            51  0.050   45.0  2602
# 53            53  0.069   65.0  2219
# 54            54  0.090   50.0  2218
# ...

# %%
breweries = pd.read_csv('../data/breweries1.csv', converters={'state':strip})

# %%
 def defineRegion(row):
        key = row['state']
        if key == 'AK' or key == 'AZ' or key == 'CO' or key == 'ID' or key == 'MT' or key == 'WY' or key == 'OR' or key == 'WA' or key == 'CA' or key == 'NV' or key == 'UT' or key == 'NM':
                    return 'west'
                else if key == 'ND' or key == 'SD' or key == 'NE' or key == 'KS' or key == 'MN' or key == 'IA' or key == 'MO' or key == 'WI' or key == 'MI' or key == 'OH' or key == 'IN':
                    return 'midwest'
                else if key == 'CT' or key == 'ME' or key == 'MA' or key == 'NH' or key == 'RI' or key == 'VT' or key == 'NY' or key == 'NJ' or key == 'PA':
                    return 'northeast'
                else :
                    return 'south'
# Out:
#      brewery_id                                 name           city state
# 0             0                   NorthGate Brewing     Minneapolis    MN
# 1             1            Against the Grain Brewery     Louisville    KY
# 2             2             Jack's Abby Craft Lagers     Framingham    MA
# 3             3            Mike Hess Brewing Company      San Diego    CA
# 4             4              Fort Point Beer Company  San Francisco    CA
# 5             5                COAST Brewing Company     Charleston    SC
# 6             6         Great Divide Brewing Company         Denver    CO
# 7             7                     Tapistry Brewing       Bridgman    MI
# 8             8                     Big Lake Brewing        Holland    MI
# 9             9           The Mitten Brewing Company   Grand Rapids    MI
# 10           10                       Brewery Vivant   Grand Rapids    MI
# 11           11                     Petoskey Brewing       Petoskey    MI
# ...

# %%
final = pd.merge(beers_final, breweries, on='brewery_id')

# %%
final.to_csv('merged_beers.csv')

# %%
# Out:
#       Unnamed: 0    abv    ibu    id  \
# 0             14  0.061   60.0  1979
# 1             21  0.099   92.0  1036
# 2             22  0.079   45.0  1024
# 3             24  0.044   42.0   876
# 4             25  0.049   17.0   802
# 5             27  0.049   17.0   800
# 6             28  0.070   70.0   799
# 7             29  0.070   70.0   797
# 8             30  0.070   70.0   796
# 9             31  0.085   52.0   531
# 10            32  0.097   94.0   432
# 11            33  0.044   42.0   353
# 12            34  0.079   45.0   321
# 13            35  0.068   65.0   173
# 14            36  0.083   35.0    11
# 15            37  0.070   65.0    10
# 16            38  0.049   17.0     9
# 17            39  0.070   82.0  2519
# 18            42  0.035   11.0  2545
# 19            43  0.045   18.0  2544
# 20            49  0.050   28.0  1870
# 21            51  0.050   45.0  2602
# 22            53  0.069   65.0  2219
# 23            54  0.090   50.0  2218
# ...
